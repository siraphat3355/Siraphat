# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import os

# %%
def range_datetime(data : pd.DataFrame):
    time = 'timestamp'if 'timestamp' in data.columns else 'datetime'
    print(data[time].iloc[0] + " - "+ data[time].iloc[-1])

# %%
m11 = pd.read_csv("dataset/meter1_phase1.csv")
m12 = pd.read_csv("dataset/meter1_phase2.csv")
m13 = pd.read_csv("dataset/meter1_phase3.csv")
m21 = pd.read_csv("dataset/meter2_phase1.csv")
m22 = pd.read_csv("dataset/meter2_phase2.csv")
m23 = pd.read_csv("dataset/meter2_phase3.csv")
weather = pd.read_csv("dataset/Weather.csv")

# %% [markdown]
# ### Look all information.

# %%
path, dirs, files = next(os.walk("dataset"))
for _,name in  enumerate(files):
    print(f"File {_} : {name}")
# Out:
# File 0 : meter1_phase2.csv
# File 1 : meter2_phase2.csv
# File 2 : Weather.csv
# File 3 : meter1_phase1.csv
# File 4 : meter2_phase3.csv
# File 5 : meter1_phase3.csv
# File 6 : people.csv
# File 7 : meter2_phase1.csv

# %% [markdown]
# ### Preprocessing Weather data.

# %%
weather["Date"] = pd.to_datetime(weather['Date'])
weather["timestamp"] = weather["Date"].astype(str) + " " + weather["Time"].astype(str)
weather['timestamp'] = pd.to_datetime(weather['timestamp'])
weather['Temp'] = weather['Temp'].map(lambda x: x.lstrip('+-').rstrip('aAbBcC%° ')).str.strip()
weather['Humidity'] = weather['Humidity'].map(lambda x: x.lstrip('+-').rstrip('aAbBcC%')).str.strip()

# %%
weather.drop(['Condition','Wind', 'Direction', 'Barometer', 'Barometer', 'Visibility', 'Date', 'Time'], axis = 1, inplace = True)

# %%
weather = weather.set_index('timestamp')
weather['Temp'] = pd.to_numeric(weather['Temp']) 
weather['Humidity'] = pd.to_numeric(weather['Humidity']) 
weather.head()
# Out:
#                      Temp  Humidity
# timestamp
# 2020-12-19 01:00:00    23        79
# 2020-12-19 04:00:00    21        83
# 2020-12-19 07:00:00    21        84
# 2020-12-19 10:00:00    23        72
# 2020-12-19 13:00:00    28        54

# %%
# weather.to_csv('cleandata/c_weather.csv', index = True)

# %% [markdown]
# ### Preprocessing Energy data.

# %%
m11.rename(columns = {'energy': 'energy1', 'power': '1powerA'}, inplace = True)
m12.rename(columns = {'power': '1powerB'}, inplace = True)
m13.rename(columns = {'power': '1powerC'}, inplace = True)

m21.rename(columns = {'energy': 'energy2', 'power': '2powerA'}, inplace = True)
m22.rename(columns = {'power': '2powerB'}, inplace = True)
m23.rename(columns = {'power': '2powerC'}, inplace = True)

# %%
Total_Energy = m11['energy1'].iloc[-1] - m11['energy1'].iloc[0]
Total_Bill1= Total_Energy * 4.0

# %%
Total_Energy = m21['energy2'].iloc[-1] - m21['energy2'].iloc[0]
Total_Bill2= Total_Energy * 4.0

# %%
print("Total Bill : ",Total_Bill1 + Total_Bill2, 'Baht.-')
# Out:
# Total Bill :  89413.625 Baht.-

# %% [markdown]
# ### Drop useless columns

# %%
m11.head()
# Out:
#              timestamp  energy_reactive    current  power_reactive  \
# 0  2020-12-19 00:00:27      37268.03125  24.109783       -1.756851
# 1  2020-12-19 00:00:57      37268.03125  24.554781       -1.800468
# 2  2020-12-19 00:01:27      37268.03125  16.898428       -1.738132
# 3  2020-12-19 00:01:57      37268.03125  16.988962       -1.746844
# 4  2020-12-19 00:02:28      37268.03125  17.363531       -1.746971
#
#    energy_reactive_to_grid     voltage        energy1  energy_to_grid  \
# 0              6832.749023  403.224792  140042.203125               0
# 1              6832.780762  402.509125  140042.296875               0
# 2              6832.790039  402.380371  140042.406250               0
# 3              6832.799805  402.881500  140042.500000               0
# 4              6832.809082  402.580475  140042.593750               0
#
#     1powerA  power_factor
# 0  5.314347      0.949463
# 1  5.400183      0.948662
# 2  3.506593      0.895972
# 3  3.533533      0.896440
# 4  3.625191      0.900855

# %%
m11 = m11.loc[:, m11.columns.intersection(['timestamp','energy1', '1powerA'])]
m12 = m12.loc[:, m12.columns.intersection(['timestamp', '1powerB'])]
m13 = m13.loc[:, m13.columns.intersection(['timestamp', '1powerC'])]

m21 = m21.loc[:, m21.columns.intersection(['timestamp','energy2', '2powerA'])]
m22 = m22.loc[:, m22.columns.intersection(['timestamp', '2powerB'])]
m23 = m23.loc[:, m23.columns.intersection(['timestamp', '2powerC'])]

# %%
m11.head()
# Out:
#              timestamp        energy1   1powerA
# 0  2020-12-19 00:00:27  140042.203125  5.314347
# 1  2020-12-19 00:00:57  140042.296875  5.400183
# 2  2020-12-19 00:01:27  140042.406250  3.506593
# 3  2020-12-19 00:01:57  140042.500000  3.533533
# 4  2020-12-19 00:02:28  140042.593750  3.625191

# %%
m11.describe()
# Out:
#              energy1       1powerA
# count   72446.000000  72446.000000
# mean   143093.745012      3.545585
# std      1764.910862      1.990561
# min    140042.203125      0.037927
# 25%    141292.316406      2.064173
# 50%    143196.015625      3.401520
# 75%    144810.968750      4.727881
# max    145398.203125     13.009340

# %% [markdown]
# ### Merge 6 table, and make frequency of data every 15 minutes

# %%
m11['timestamp'] = pd.to_datetime(m11['timestamp'])
m12['timestamp'] = pd.to_datetime(m12['timestamp'])
m13['timestamp'] = pd.to_datetime(m13['timestamp'])
m1 = pd.merge_asof(m11, m12, on='timestamp', tolerance=pd.Timedelta("30ms"))
m1 = pd.merge_asof(m1, m13, on='timestamp', tolerance=pd.Timedelta("30ms"))
m1 = m1.groupby(pd.Grouper(freq='15T',key='timestamp')).mean()

# %%
m21['timestamp'] = pd.to_datetime(m21['timestamp'])
m22['timestamp'] = pd.to_datetime(m22['timestamp'])
m23['timestamp'] = pd.to_datetime(m23['timestamp'])
m2 = pd.merge_asof(m21, m22, on='timestamp', tolerance=pd.Timedelta("30ms"))
m2 = pd.merge_asof(m2, m23, on='timestamp', tolerance=pd.Timedelta("30ms"))
m2 = m2.groupby(pd.Grouper(freq='15T',key='timestamp')).mean()

# %%
Ans = pd.merge_asof(m1, m2, on='timestamp', tolerance=pd.Timedelta("30ms"))
Ans = Ans.sort_values(by="timestamp")
Ans['timestamp'] = Ans['timestamp'].dt.floor('Min')
Ans.fillna(0, inplace = True)
Ans
# Out:
#                timestamp        energy1   1powerA   1powerB   1powerC  \
# 0    2020-12-19 00:00:00  140043.391146  3.255264  1.724024  4.219208
# 1    2020-12-19 00:15:00  140045.516146  2.812916  1.777869  3.784695
# 2    2020-12-19 00:30:00  140047.771875  2.818559  1.857305  5.051593
# 3    2020-12-19 00:45:00  140049.958854  3.025429  1.750408  3.142562
# 4    2020-12-19 01:00:00  140051.855729  2.585936  1.698523  3.203603
# ...                  ...            ...       ...       ...       ...
# 2466 2021-01-13 16:30:00  145397.501562  0.613766  0.000000  0.000000
# 2467 2021-01-13 16:45:00  145397.653533  0.801505  0.000000  0.000000
# 2468 2021-01-13 17:00:00  145397.819111  0.692847  0.000000  0.190294
# 2469 2021-01-13 17:15:00  145398.007212  0.603717  0.000000  0.190307
# 2470 2021-01-13 17:30:00  145398.152083  0.636011  0.000000  0.190102
#
#             energy2    2powerA    2powerB   2powerC
# 0     304480.550000   9.229886   9.135354  7.701414
# 1     304487.406250   9.877761   9.159706  9.134663
# 2     304494.794792  11.516459  10.269925  9.393754
# 3     304502.237500  11.469462   8.602655  8.568154
# 4     304509.079167  10.091112   8.232744  8.462210
# ...             ...        ...        ...       ...
# 2466  321467.808333   1.384582   1.098190  0.000000
# 2467  321468.691667   1.390026   1.098095  0.000000
# 2468  321469.573958   1.394100   1.100963  0.000000
# 2469  321470.480208   1.623777   1.326716  0.000000
# 2470  321472.107292   3.006761   2.706538  0.000000
#
# [2471 rows x 9 columns]

# %%
Ans = Ans.merge(weather, on='timestamp', how='left')
Ans
# Out:
#                timestamp        energy1   1powerA   1powerB   1powerC  \
# 0    2020-12-19 00:00:00  140043.391146  3.255264  1.724024  4.219208
# 1    2020-12-19 00:15:00  140045.516146  2.812916  1.777869  3.784695
# 2    2020-12-19 00:30:00  140047.771875  2.818559  1.857305  5.051593
# 3    2020-12-19 00:45:00  140049.958854  3.025429  1.750408  3.142562
# 4    2020-12-19 01:00:00  140051.855729  2.585936  1.698523  3.203603
# ...                  ...            ...       ...       ...       ...
# 2466 2021-01-13 16:30:00  145397.501562  0.613766  0.000000  0.000000
# 2467 2021-01-13 16:45:00  145397.653533  0.801505  0.000000  0.000000
# 2468 2021-01-13 17:00:00  145397.819111  0.692847  0.000000  0.190294
# 2469 2021-01-13 17:15:00  145398.007212  0.603717  0.000000  0.190307
# 2470 2021-01-13 17:30:00  145398.152083  0.636011  0.000000  0.190102
#
#             energy2    2powerA    2powerB   2powerC  Temp  Humidity
# 0     304480.550000   9.229886   9.135354  7.701414   NaN       NaN
# 1     304487.406250   9.877761   9.159706  9.134663   NaN       NaN
# 2     304494.794792  11.516459  10.269925  9.393754   NaN       NaN
# 3     304502.237500  11.469462   8.602655  8.568154   NaN       NaN
# 4     304509.079167  10.091112   8.232744  8.462210  23.0      79.0
# ...             ...        ...        ...       ...   ...       ...
# 2466  321467.808333   1.384582   1.098190  0.000000   NaN       NaN
# 2467  321468.691667   1.390026   1.098095  0.000000   NaN       NaN
# 2468  321469.573958   1.394100   1.100963  0.000000   NaN       NaN
# 2469  321470.480208   1.623777   1.326716  0.000000   NaN       NaN
# 2470  321472.107292   3.006761   2.706538  0.000000   NaN       NaN
#
# [2471 rows x 11 columns]

# %% [markdown]
# ### Fill nan value

# %%
Ans['Temp'].fillna(method='ffill', inplace=True)
Ans['Temp'].fillna(method='bfill', inplace=True)
Ans['Humidity'].fillna(method='ffill', inplace=True)
Ans['Humidity'].fillna(method='bfill', inplace=True)

# %%
Ans.head()
# Out:
#             timestamp        energy1   1powerA   1powerB   1powerC  \
# 0 2020-12-19 00:00:00  140043.391146  3.255264  1.724024  4.219208
# 1 2020-12-19 00:15:00  140045.516146  2.812916  1.777869  3.784695
# 2 2020-12-19 00:30:00  140047.771875  2.818559  1.857305  5.051593
# 3 2020-12-19 00:45:00  140049.958854  3.025429  1.750408  3.142562
# 4 2020-12-19 01:00:00  140051.855729  2.585936  1.698523  3.203603
#
#          energy2    2powerA    2powerB   2powerC  Temp  Humidity
# 0  304480.550000   9.229886   9.135354  7.701414  23.0      79.0
# 1  304487.406250   9.877761   9.159706  9.134663  23.0      79.0
# 2  304494.794792  11.516459  10.269925  9.393754  23.0      79.0
# 3  304502.237500  11.469462   8.602655  8.568154  23.0      79.0
# 4  304509.079167  10.091112   8.232744  8.462210  23.0      79.0

# %%
Ans.to_csv('Outcome.csv', index = True)

# %% [markdown]
# ### People data

# %%
people = pd.read_csv("dataset/people.csv")
people['datetime'] = pd.to_datetime(people['datetime'])
people
# Out:
#                 datetime  zone1  zone2  zone3  zone4
# 0    2020-12-15 22:01:44      0      2      0      3
# 1    2020-12-15 22:03:32      0      0      0      3
# 2    2020-12-15 22:05:09      0      0      0      4
# 3    2020-12-15 22:06:45      0      0      0      4
# 4    2020-12-15 22:08:15      0      0      0      2
# ...                  ...    ...    ...    ...    ...
# 3624 2021-01-11 09:40:12      2      2      0      2
# 3625 2021-01-11 09:41:50      0      2      0      0
# 3626 2021-01-11 09:43:09      0      2      0      0
# 3627 2021-01-11 10:17:42      0      0      0      2
# 3628 2021-01-11 10:25:02      0      0      0      2
#
# [3629 rows x 5 columns]

# %%
people = people.groupby(pd.Grouper(freq='d',key='datetime')).mean()
Apeople = pd.DataFrame()
Apeople['Total_people'] = people.zone1 + people.zone2 + people.zone3 + people.zone4

# %% [markdown]
# ### For Power Bi

# %%
# Ans = Ans.resample('d', on='timestamp').mean().dropna(how='all')

# %%
# Ans['Day'] = Ans.index.day
# Ans['Month'] = Ans.index.month
# Ans['hour'] = Ans.index.hour
# Ans['min'] = Ans.index.minute

# %%
Ans['Total_Power'] = Ans['1powerA'] + Ans['1powerB'] + Ans['1powerC'] + Ans['2powerA'] + Ans['2powerB'] + Ans['2powerC']

# %%
Ans['Bill'] = Ans['Total_Power'] * 24 * 4

# %%
initial = Ans['energy1'].iloc[0] + Ans['energy2'].iloc[0]
initial
# Out:
# 444523.94114583335

# %%
Ans['Total_Energy'] = Ans['energy1'] + Ans['energy2'] - initial

# %%
Ans
# Out:
#                timestamp        energy1   1powerA   1powerB   1powerC  \
# 0    2020-12-19 00:00:00  140043.391146  3.255264  1.724024  4.219208
# 1    2020-12-19 00:15:00  140045.516146  2.812916  1.777869  3.784695
# 2    2020-12-19 00:30:00  140047.771875  2.818559  1.857305  5.051593
# 3    2020-12-19 00:45:00  140049.958854  3.025429  1.750408  3.142562
# 4    2020-12-19 01:00:00  140051.855729  2.585936  1.698523  3.203603
# ...                  ...            ...       ...       ...       ...
# 2466 2021-01-13 16:30:00  145397.501562  0.613766  0.000000  0.000000
# 2467 2021-01-13 16:45:00  145397.653533  0.801505  0.000000  0.000000
# 2468 2021-01-13 17:00:00  145397.819111  0.692847  0.000000  0.190294
# 2469 2021-01-13 17:15:00  145398.007212  0.603717  0.000000  0.190307
# 2470 2021-01-13 17:30:00  145398.152083  0.636011  0.000000  0.190102
#
#             energy2    2powerA    2powerB   2powerC  Temp  Humidity  \
# 0     304480.550000   9.229886   9.135354  7.701414  23.0      79.0
# 1     304487.406250   9.877761   9.159706  9.134663  23.0      79.0
# 2     304494.794792  11.516459  10.269925  9.393754  23.0      79.0
# 3     304502.237500  11.469462   8.602655  8.568154  23.0      79.0
# 4     304509.079167  10.091112   8.232744  8.462210  23.0      79.0
# ...             ...        ...        ...       ...   ...       ...
# 2466  321467.808333   1.384582   1.098190  0.000000  21.0      58.0
# 2467  321468.691667   1.390026   1.098095  0.000000  21.0      58.0
# 2468  321469.573958   1.394100   1.100963  0.000000  21.0      58.0
# 2469  321470.480208   1.623777   1.326716  0.000000  21.0      58.0
# 2470  321472.107292   3.006761   2.706538  0.000000  21.0      58.0
#
#       Total_Power         Bill  Total_Energy
# 0       35.265151  3385.454523      0.000000
# 1       36.547610  3508.570593      8.981250
# 2       40.907596  3927.129181     18.625521
# 3       36.558670  3509.632336     28.255208
# 4       34.274128  3290.316313     36.993750
# ...           ...          ...           ...
# 2466     3.096538   297.267665  22341.368750
# 2467     3.289626   315.804128  22342.404053
# 2468     3.378202   324.307428  22343.451923
# 2469     3.744518   359.473731  22344.546274
# 2470     6.539413   627.783648  22346.318229
#
# [2471 rows x 14 columns]

# %%
Ans = Ans.resample('d', on='timestamp').mean().dropna(how='all')

# %%
Ans
# Out:
#                   energy1   1powerA   1powerB   1powerC        energy2  \
# timestamp
# 2020-12-19  140161.659058  4.234113  2.694683  3.937955  304921.719935
# 2020-12-20  140428.035037  4.422865  0.477503  3.695493  305925.793368
# 2020-12-21  140711.093556  4.253141  0.000000  3.475088  306834.831223
# 2020-12-22  140956.903352  3.586500  0.000000  3.340292  307654.140648
# 2020-12-23  139708.559681  3.252361  0.000000  3.182525  305168.814787
# 2020-12-24  141399.426717  3.446294  0.000000  3.102851  309097.546380
# 2020-12-25  132799.332106  4.300166  0.000000  4.145159  290502.220903
# 2020-12-26  131606.312487  4.525475  0.000000  3.662754  288030.046110
# 2020-12-27  137823.433827  5.965896  0.000000  4.949633  301840.341584
# 2020-12-28  133714.472053  4.666896  0.000000  4.167851  293012.736886
# 2020-12-29  138451.185271  3.928472  0.000000  3.155631  303694.636503
# 2020-12-30  138685.946386  4.485063  0.000000  3.783853  304473.562873
# 2020-12-31  131531.735582  5.827514  0.000000  4.984332  288926.736969
# 2021-01-01  139348.751204  4.213868  0.000000  3.605711  306293.585458
# 2021-01-02  141101.280191  3.833839  0.000000  2.963440  310413.649611
# 2021-01-03  139803.460812  2.992865  0.000000  2.410758  307844.254278
# 2021-01-04  130927.944799  2.164763  0.000000  2.144150  288528.610341
# 2021-01-05  129576.951549  2.960219  0.000000  2.598240  285617.942718
# 2021-01-06  131240.216920  2.825568  0.000000  2.037939  289283.241099
# 2021-01-07  132923.553104  2.865791  0.000000  2.213760  292988.816122
# 2021-01-08  123979.264727  1.704740  0.000000  1.103361  273362.304749
# 2021-01-09  140698.623249  1.677915  0.000000  0.543332  310401.977719
# 2021-01-10  139255.213055  1.553238  0.000000  0.362344  307384.192794
# 2021-01-11  134758.760324  0.662878  0.000000  0.050532  297629.157347
# 2021-01-12  133264.597297  0.463769  0.000000  0.045758  294500.906722
# 2021-01-13  129010.925863  0.461091  0.000000  0.012086  285215.250006
#
#               2powerA    2powerB    2powerC       Temp   Humidity  \
# timestamp
# 2020-12-19  16.839585  12.184673  12.359746  24.375000  70.416667
# 2020-12-20  16.234833  12.270182  11.961021  22.458333  73.375000
# 2020-12-21  13.154028  10.822928  11.872286  21.875000  56.791667
# 2020-12-22  12.191691   9.298458  10.220017  19.916667  60.375000
# 2020-12-23  10.765692   8.979339   9.260268  19.333333  68.791667
# 2020-12-24  12.096298   9.945538   9.687798  20.208333  67.083333
# 2020-12-25  11.971994   9.702631   8.841125  21.166667  68.916667
# 2020-12-26  12.895971  10.432744   9.875908  24.000000  68.416667
# 2020-12-27  15.559503  12.356949   0.861798  25.125000  71.041667
# 2020-12-28  14.414483  11.811853   0.000000  24.916667  67.041667
# 2020-12-29  13.712041  10.029500   0.000000  23.208333  63.916667
# 2020-12-30  13.213311   8.819965   0.000000  22.541667  63.833333
# 2020-12-31  14.474349  11.782148   0.000000  23.958333  64.250000
# 2021-01-01  15.140649  12.320366   0.000000  23.333333  59.916667
# 2021-01-02  11.312703  11.368946   0.000000  22.000000  69.000000
# 2021-01-03   9.457695  10.380449   0.000000  22.000000  69.000000
# 2021-01-04   5.658034   5.897996   0.000000  22.000000  69.000000
# 2021-01-05   5.174118   5.664646   0.000000  22.000000  69.000000
# 2021-01-06   5.074996   4.844797   0.000000  22.000000  69.000000
# 2021-01-07   6.446649   4.773798   0.000000  22.000000  69.000000
# 2021-01-08   5.209569   5.056447   0.000000  22.000000  69.000000
# 2021-01-09   4.517320   5.036194   0.000000  22.000000  69.000000
# 2021-01-10   3.685138   4.448761   0.000000  22.000000  69.000000
# 2021-01-11   2.853994   3.078688   0.000000  22.000000  69.000000
# 2021-01-12   2.813109   2.965036   0.000000  22.000000  69.000000
# 2021-01-13   1.768297   1.684205   0.000000  17.000000  66.056338
#
#             Total_Power         Bill  Total_Energy
# timestamp
# 2020-12-19    52.250755  5016.072524    559.437847
# 2020-12-20    49.061896  4709.942041   1829.887259
# 2020-12-21    43.577470  4183.437076   3021.983633
# 2020-12-22    38.636957  3709.147908   4087.102854
# 2020-12-23    35.440186  3402.257840    353.433323
# 2020-12-24    38.278779  3674.762804   5973.031951
# 2020-12-25    38.961074  3740.263118 -21222.388137
# 2020-12-26    41.392852  3973.713802 -24887.582549
# 2020-12-27    39.693779  3810.602828  -4860.165735
# 2020-12-28    35.061083  3365.863922 -17796.732207
# 2020-12-29    30.825645  2959.261927  -2378.119372
# 2020-12-30    30.302193  2909.010546  -1364.431886
# 2020-12-31    37.068343  3558.560943 -24065.468595
# 2021-01-01    35.280595  3386.937082   1118.395516
# 2021-01-02    29.478928  2829.977134   6990.988656
# 2021-01-03    25.241767  2423.209619   3123.773944
# 2021-01-04    15.864943  1523.034486 -25067.386005
# 2021-01-05    16.397223  1574.133405 -29329.046878
# 2021-01-06    14.783300  1419.196829 -24000.483127
# 2021-01-07    16.299998  1564.799809 -18611.571920
# 2021-01-08    13.074117  1255.115229 -47182.371670
# 2021-01-09    11.774761  1130.377009   6576.659822
# 2021-01-10    10.049481   964.750213   2115.464703
# 2021-01-11     6.646092   638.024841 -12136.023475
# 2021-01-12     6.287672   603.616493 -16758.437127
# 2021-01-13     3.925679   376.865215 -30297.765277

# %%
Ans.Bill.sum()
# Out:
# 68702.93464311391

# %%
Ans.to_csv('OutcomeBI.csv', index = True)
